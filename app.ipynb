# %%
# %pip install flask_bcrypt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting flask_bcrypt
#   Using cached Flask_Bcrypt-1.0.1-py3-none-any.whl (6.0 kB)
# Requirement already satisfied: Flask in /Users/rishithakker/Library/Python/3.9/lib/python/site-packages (from flask_bcrypt) (3.0.3)
# Collecting bcrypt>=3.1.1
#   Using cached bcrypt-4.1.3-cp39-abi3-macosx_10_12_universal2.whl (506 kB)
# Requirement already satisfied: itsdangerous>=2.1.2 in /Users/rishithakker/Library/Python/3.9/lib/python/site-packages (from Flask->flask_bcrypt) (2.2.0)
# Requirement already satisfied: blinker>=1.6.2 in /Users/rishithakker/Library/Python/3.9/lib/python/site-packages (from Flask->flask_bcrypt) (1.8.2)
# Requirement already satisfied: importlib-metadata>=3.6.0 in /Users/rishithakker/Library/Python/3.9/lib/python/site-packages (from Flask->flask_bcrypt) (7.1.0)
# Requirement already satisfied: Werkzeug>=3.0.0 in /Users/rishithakker/Library/Python/3.9/lib/python/site-packages (from Flask->flask_bcrypt) (3.0.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /Users/rishithakker/Library/Python/3.9/lib/python/site-packages (from Flask->flask_bcrypt) (3.1.4)
# Requirement already satisfied: click>=8.1.3 in /Users/rishithakker/Library/Python/3.9/lib/python/site-packages (from Flask->flask_bcrypt) (8.1.7)
# Requirement already satisfied: zipp>=0.5 in /Users/rishithakker/Library/Python/3.9/lib/python/site-packages (from importlib-metadata>=3.6.0->Flask->flask_bcrypt) (3.18.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/rishithakker/Library/Python/3.9/lib/python/site-packages (from Jinja2>=3.1.2->Flask->flask_bcrypt) (2.1.5)
# Installing collected packages: bcrypt, flask-bcrypt
# Successfully installed bcrypt-4.1.3 flask-bcrypt-1.0.1
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the '/Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install config
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting config
#   Downloading config-0.5.1-py2.py3-none-any.whl (20 kB)
# Installing collected packages: config
# Successfully installed config-0.5.1
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the '/Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install models
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting models
#   Downloading models-0.9.3.tar.gz (16 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /Applications/Xcode.app/Contents/Developer/usr/bin/python3 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_0603a8327cc244b7a2f1ab56315285fa/setup.py'"'"'; __file__='"'"'/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_0603a8327cc244b7a2f1ab56315285fa/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-pip-egg-info-carexy8x
#          cwd: /private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_0603a8327cc244b7a2f1ab56315285fa/
#     Complete output (7 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_0603a8327cc244b7a2f1ab56315285fa/setup.py", line 25, in <module>
#         import models
#       File "/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_0603a8327cc244b7a2f1ab56315285fa/models/__init__.py", line 23, in <module>
#         from base import *
#     ModuleNotFoundError: No module named 'base'
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/92/3c/ac1ddde60c02b5a46993bd3c6f4c66a9dbc100059da8333178ce17a22db5/models-0.9.3.tar.gz#sha256=b5aa29c6b57a667cda667dd9fbd33bbd15c14cc285e57dda64f4f4c0fd35e0ae (from https://pypi.org/simple/models/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading models-0.9.2.tar.gz (16 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /Applications/Xcode.app/Contents/Developer/usr/bin/python3 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_e2f70f82ccf9465488d6f153327560d0/setup.py'"'"'; __file__='"'"'/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_e2f70f82ccf9465488d6f153327560d0/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-pip-egg-info-e4p217iv
#          cwd: /private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_e2f70f82ccf9465488d6f153327560d0/
#     Complete output (7 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_e2f70f82ccf9465488d6f153327560d0/setup.py", line 25, in <module>
#         import models
#       File "/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_e2f70f82ccf9465488d6f153327560d0/models/__init__.py", line 23, in <module>
#         from base import *
#     ModuleNotFoundError: No module named 'base'
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/44/3a/8cd3c08995d89e87e74a9aa04784dcb9ade25c03250c281376ce4942d7f5/models-0.9.2.tar.gz#sha256=308be4d5cb707c63f967c591111a8675fe3eaa59c04516e5f6c7fff5e026ece0 (from https://pypi.org/simple/models/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading models-0.9.1.tar.gz (16 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /Applications/Xcode.app/Contents/Developer/usr/bin/python3 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_d600aca8c9814a8e91e06d1ee21125c4/setup.py'"'"'; __file__='"'"'/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_d600aca8c9814a8e91e06d1ee21125c4/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-pip-egg-info-n63dkgzv
#          cwd: /private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_d600aca8c9814a8e91e06d1ee21125c4/
#     Complete output (7 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_d600aca8c9814a8e91e06d1ee21125c4/setup.py", line 25, in <module>
#         import models
#       File "/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_d600aca8c9814a8e91e06d1ee21125c4/models/__init__.py", line 23, in <module>
#         from base import *
#     ModuleNotFoundError: No module named 'base'
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/10/1d/dd6ae3703251520729a9203ce95c436837ca28e0ee6794538efb136ac0e4/models-0.9.1.tar.gz#sha256=78eb7e8cef14864cda9ec5c1911f3c0771671734c71945ec4f908c505d3be8f9 (from https://pypi.org/simple/models/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading models-0.9.0.tar.gz (14 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /Applications/Xcode.app/Contents/Developer/usr/bin/python3 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_d74d780d15a44bc9b6957b4412629501/setup.py'"'"'; __file__='"'"'/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_d74d780d15a44bc9b6957b4412629501/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-pip-egg-info-7uqk9sqy
#          cwd: /private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_d74d780d15a44bc9b6957b4412629501/
#     Complete output (7 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_d74d780d15a44bc9b6957b4412629501/setup.py", line 25, in <module>
#         import models
#       File "/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_d74d780d15a44bc9b6957b4412629501/models/__init__.py", line 23, in <module>
#         from base import *
#     ModuleNotFoundError: No module named 'base'
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/05/2a/025b493fac59ba30b4ba63c15e72200b0d39a44f22a226f3d69b176a03df/models-0.9.0.tar.gz#sha256=9c16463aef8fe05e856d74c084035bac1d53936f6274444611eee7cb2ccc4556 (from https://pypi.org/simple/models/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading models-0.8.0.tar.gz (14 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /Applications/Xcode.app/Contents/Developer/usr/bin/python3 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_8f56eabe93e943df8c0c9101c415cfe0/setup.py'"'"'; __file__='"'"'/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_8f56eabe93e943df8c0c9101c415cfe0/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-pip-egg-info-v1svt4n3
#          cwd: /private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_8f56eabe93e943df8c0c9101c415cfe0/
#     Complete output (7 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_8f56eabe93e943df8c0c9101c415cfe0/setup.py", line 25, in <module>
#         import models
#       File "/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_8f56eabe93e943df8c0c9101c415cfe0/models/__init__.py", line 23, in <module>
#         from base import *
#     ModuleNotFoundError: No module named 'base'
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/63/e1/b6f02f5df8e27da6a3ea3b7f61ff7ab2d17b4b98290a54799c1bd712b883/models-0.8.0.tar.gz#sha256=c2d01e2c83fb39866ad622e0dbe0e211cf694b5148550cca079411249171c747 (from https://pypi.org/simple/models/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading models-0.7.0.tar.gz (14 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /Applications/Xcode.app/Contents/Developer/usr/bin/python3 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_e9fa48946a0a4eb6a5c689eea19cc3b0/setup.py'"'"'; __file__='"'"'/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_e9fa48946a0a4eb6a5c689eea19cc3b0/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-pip-egg-info-dxe_96hl
#          cwd: /private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_e9fa48946a0a4eb6a5c689eea19cc3b0/
#     Complete output (7 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_e9fa48946a0a4eb6a5c689eea19cc3b0/setup.py", line 25, in <module>
#         import models
#       File "/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_e9fa48946a0a4eb6a5c689eea19cc3b0/models/__init__.py", line 23, in <module>
#         from base import *
#     ModuleNotFoundError: No module named 'base'
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/09/88/72909bdb09041e6adcc90944f8e9a08fb578aaa6e7699e80a9c147ff7c1f/models-0.7.0.tar.gz#sha256=e3d01ad00a6ec6831de6138a3f986c2efb7bd9355d8bb3f5b700eb2e96b6e3e7 (from https://pypi.org/simple/models/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading models-0.4.0.tar.gz (11 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /Applications/Xcode.app/Contents/Developer/usr/bin/python3 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_9f944247f5c140658d411c1dc0cc216f/setup.py'"'"'; __file__='"'"'/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_9f944247f5c140658d411c1dc0cc216f/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-pip-egg-info-yluctc05
#          cwd: /private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_9f944247f5c140658d411c1dc0cc216f/
#     Complete output (7 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_9f944247f5c140658d411c1dc0cc216f/setup.py", line 25, in <module>
#         import models
#       File "/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_9f944247f5c140658d411c1dc0cc216f/models/__init__.py", line 23, in <module>
#         from base import *
#     ModuleNotFoundError: No module named 'base'
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/79/44/59bdda622faaec86c9db3f85270e29a3485936753b779c8210d3c0499ccb/models-0.4.0.tar.gz#sha256=80314c00ee1e8b19b4536107daac00b4e986f048e58d73530a00348322bc4399 (from https://pypi.org/simple/models/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading models-0.3.0.tar.gz (11 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /Applications/Xcode.app/Contents/Developer/usr/bin/python3 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_5deacf337e6e4ecf9c29141cefbdfb50/setup.py'"'"'; __file__='"'"'/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_5deacf337e6e4ecf9c29141cefbdfb50/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-pip-egg-info-kxfkwdcs
#          cwd: /private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_5deacf337e6e4ecf9c29141cefbdfb50/
#     Complete output (7 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_5deacf337e6e4ecf9c29141cefbdfb50/setup.py", line 25, in <module>
#         import models
#       File "/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_5deacf337e6e4ecf9c29141cefbdfb50/models/__init__.py", line 23, in <module>
#         from base import *
#     ModuleNotFoundError: No module named 'base'
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/fb/dc/fd2068f4cc4f275a1a2d41a2ca6a6b3a0d49c7e86ba3a30d2fbf15731f7a/models-0.3.0.tar.gz#sha256=ce0350c757e27dcf7476d9a3f030a3f408c0b318a6b1153a83db8206766fae10 (from https://pypi.org/simple/models/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading models-0.2.0.tar.gz (11 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /Applications/Xcode.app/Contents/Developer/usr/bin/python3 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_3420083190d3484cbc0d6faa19cef069/setup.py'"'"'; __file__='"'"'/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_3420083190d3484cbc0d6faa19cef069/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-pip-egg-info-t_b4aq15
#          cwd: /private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_3420083190d3484cbc0d6faa19cef069/
#     Complete output (7 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_3420083190d3484cbc0d6faa19cef069/setup.py", line 25, in <module>
#         import models
#       File "/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_3420083190d3484cbc0d6faa19cef069/models/__init__.py", line 23, in <module>
#         from base import *
#     ModuleNotFoundError: No module named 'base'
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/27/62/62ebd85760e4f812753056b4763f0a866cdcbc08ee6ccc2b81a2f5fb2202/models-0.2.0.tar.gz#sha256=2f5982ef56afe9239f81f5d6a461823e0dc267c6212c06754a0863b98dad60a4 (from https://pypi.org/simple/models/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading models-0.1.1.tar.gz (11 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /Applications/Xcode.app/Contents/Developer/usr/bin/python3 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_05b84aab782944748a0d63b7dcd2ba24/setup.py'"'"'; __file__='"'"'/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_05b84aab782944748a0d63b7dcd2ba24/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-pip-egg-info-aj3cpted
#          cwd: /private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_05b84aab782944748a0d63b7dcd2ba24/
#     Complete output (7 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_05b84aab782944748a0d63b7dcd2ba24/setup.py", line 25, in <module>
#         import models
#       File "/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_05b84aab782944748a0d63b7dcd2ba24/models/__init__.py", line 23, in <module>
#         from base import *
#     ModuleNotFoundError: No module named 'base'
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/ca/81/53baac8e352f956a23568f285a72bcd2d8cc04321022f0196de5eaf5e5e4/models-0.1.1.tar.gz#sha256=b117db9acd5a232f4333a5927385320826168514364e86d1dbaba44b01fab1a9 (from https://pypi.org/simple/models/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading models-0.1.0.tar.gz (11 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /Applications/Xcode.app/Contents/Developer/usr/bin/python3 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_863ad56bf01b4b888abdbb733711fe59/setup.py'"'"'; __file__='"'"'/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_863ad56bf01b4b888abdbb733711fe59/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-pip-egg-info-bjkjxoip
#          cwd: /private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_863ad56bf01b4b888abdbb733711fe59/
#     Complete output (7 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_863ad56bf01b4b888abdbb733711fe59/setup.py", line 25, in <module>
#         import models
#       File "/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_863ad56bf01b4b888abdbb733711fe59/models/__init__.py", line 23, in <module>
#         from base import *
#     ModuleNotFoundError: No module named 'base'
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/ad/3b/596d1bb079039dc29b92692e59b87d7f352a15e25cca6b5b304ff3efce9a/models-0.1.0.tar.gz#sha256=0b74111b909079ef6baaa10e1619ff5aaeaace807f0bcc948650c38e81534203 (from https://pypi.org/simple/models/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading models-0.0.5.tar.gz (6.4 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /Applications/Xcode.app/Contents/Developer/usr/bin/python3 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_cf875864010d45e2a6968bedccb647ea/setup.py'"'"'; __file__='"'"'/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_cf875864010d45e2a6968bedccb647ea/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-pip-egg-info-pftdv_tn
#          cwd: /private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_cf875864010d45e2a6968bedccb647ea/
#     Complete output (7 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_cf875864010d45e2a6968bedccb647ea/setup.py", line 24, in <module>
#         import models
#       File "/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_cf875864010d45e2a6968bedccb647ea/models/__init__.py", line 23, in <module>
#         from base import *
#     ModuleNotFoundError: No module named 'base'
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/b9/12/3a057a76ef4063e25584e922228e82f9fb0ab20e888e97dd4d109d017207/models-0.0.5.tar.gz#sha256=5832d3221cce8918872873b7aa8436d80c829de1b7ba4ec21944c9c361a12386 (from https://pypi.org/simple/models/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading models-0.0.4.tar.gz (6.1 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /Applications/Xcode.app/Contents/Developer/usr/bin/python3 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_75a3d6ee08c8461393d5fd84bc32caef/setup.py'"'"'; __file__='"'"'/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_75a3d6ee08c8461393d5fd84bc32caef/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-pip-egg-info-xc_vnluc
#          cwd: /private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_75a3d6ee08c8461393d5fd84bc32caef/
#     Complete output (7 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_75a3d6ee08c8461393d5fd84bc32caef/setup.py", line 24, in <module>
#         import models
#       File "/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_75a3d6ee08c8461393d5fd84bc32caef/models/__init__.py", line 23, in <module>
#         from base import *
#     ModuleNotFoundError: No module named 'base'
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/e6/6a/0a4cb29c5d32ddbe06080deebd1e4f8896f6de56f954d690d492e8044b91/models-0.0.4.tar.gz#sha256=4537a1b50b1efb54ff52762f6108be8afcfc194927380d948d7d983ac2557a98 (from https://pypi.org/simple/models/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading models-0.0.3.tar.gz (6.2 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /Applications/Xcode.app/Contents/Developer/usr/bin/python3 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_ee614f0f21804a3dacc99d1b53a0e3ac/setup.py'"'"'; __file__='"'"'/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_ee614f0f21804a3dacc99d1b53a0e3ac/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-pip-egg-info-1not_6w7
#          cwd: /private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_ee614f0f21804a3dacc99d1b53a0e3ac/
#     Complete output (7 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_ee614f0f21804a3dacc99d1b53a0e3ac/setup.py", line 24, in <module>
#         import models
#       File "/private/var/folders/68/nsld5q1x4yz4s1zxg64r12p00000gn/T/pip-install-wzjoqux0/models_ee614f0f21804a3dacc99d1b53a0e3ac/models/__init__.py", line 23, in <module>
#         from base import *
#     ModuleNotFoundError: No module named 'base'
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/68/35/b990e771f13982d98385774c651c0c90baec4b4ef19c752b5e6add126d3f/models-0.0.3.tar.gz#sha256=9bb0315231b46d53df62c63321c33fc6935ca58db629e3aef09c735b781a9d8b (from https://pypi.org/simple/models/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# ERROR: Could not find a version that satisfies the requirement models (from versions: 0.0.3, 0.0.4, 0.0.5, 0.1.0, 0.1.1, 0.2.0, 0.3.0, 0.4.0, 0.7.0, 0.8.0, 0.9.0, 0.9.1, 0.9.2, 0.9.3)
# ERROR: No matching distribution found for models
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the '/Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install forms
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement forms (from versions: none)
# ERROR: No matching distribution found for forms
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the '/Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
from flask import Flask, render_template, redirect, url_for, flash, request
from flask_sqlalchemy import SQLAlchemy
from flask_bcrypt import Bcrypt
from flask_login import LoginManager, login_user, current_user, logout_user, login_required
from config import Config
from models.ipynb import db, User
from forms.ipynb import RegistrationForm, LoginForm, UserForm

app = Flask(__name__)
app.config.from_object(Config)
db.init_app(app)
bcrypt = Bcrypt(app)
login_manager = LoginManager(app)
login_manager.login_view = 'login'

@login_manager.user_loader
def load_user(user_id):
    return User.query.get(int(user_id))

@app.before_first_request
def create_tables():
    db.create_all()

@app.route('/')
@login_required
def index():
    users = User.query.all()
    return render_template('index.html', users=users)

@app.route('/add', methods=['GET', 'POST'])
@login_required
def add_user():
    form = UserForm()
    if form.validate_on_submit():
        user = User(name=form.name.data, email=form.email.data, phone=form.phone.data, bio=form.bio.data, password=bcrypt.generate_password_hash('default').decode('utf-8'))
        db.session.add(user)
        db.session.commit()
        flash('User added successfully!', 'success')
        return redirect(url_for('index'))
    return render_template('add_user.html', form=form)

@app.route('/edit/<int:user_id>', methods=['GET', 'POST'])
@login_required
def edit_user(user_id):
    user = User.query.get_or_404(user_id)
    form = UserForm(obj=user)
    if form.validate_on_submit():
        user.name = form.name.data
        user.email = form.email.data
        user.phone = form.phone.data
        user.bio = form.bio.data
        db.session.commit()
        flash('User updated successfully!', 'success')
        return redirect(url_for('index'))
    return render_template('edit_user.html', form=form)

@app.route('/delete/<int:user_id>', methods=['GET', 'POST'])
@login_required
def delete_user(user_id):
    user = User.query.get_or_404(user_id)
    db.session.delete(user)
    db.session.commit()
    flash('User deleted successfully!', 'success')
    return redirect(url_for('index'))

@app.route('/search', methods=['POST'])
@login_required
def search():
    search_term = request.form.get('search_term')
    users = User.query.filter(User.name.like(f'%{search_term}%')).all()
    return render_template('index.html', users=users)

@app.route('/register', methods=['GET', 'POST'])
def register():
    if current_user.is_authenticated:
        return redirect(url_for('index'))
    form = RegistrationForm()
    if form.validate_on_submit():
        hashed_password = bcrypt.generate_password_hash(form.password.data).decode('utf-8')
        user = User(name=form.name.data, email=form.email.data, phone=form.phone.data, bio=form.bio.data, password=hashed_password)
        db.session.add(user)
        db.session.commit()
        flash('Your account has been created! You are now able to log in', 'success')
        return redirect(url_for('login'))
    return render_template('register.html', form=form)

@app.route('/login', methods=['GET', 'POST'])
def login():
    if current_user.is_authenticated:
        return redirect(url_for('index'))
    form = LoginForm()
    if form.validate_on_submit():
        user = User.query.filter_by(email=form.email.data).first()
        if user and bcrypt.check_password_hash(user.password, form.password.data):
            login_user(user, remember=True)
            return redirect(url_for('index'))
        else:
            flash('Login Unsuccessful. Please check email and password', 'danger')
    return render_template('login.html', form=form)

@app.route('/logout')
def logout():
    logout_user()
    return redirect(url_for('login'))

if __name__ == '__main__':
    app.run(debug=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 6
#       4 from flask_login import LoginManager, login_user, current_user, logout_user, login_required
#       5 from config import Config
# ----> 6 from models.ipynb import db, User
#       7 from forms.ipynb import RegistrationForm, LoginForm, UserForm
#       9 app = Flask(__name__)
#
# ModuleNotFoundError: No module named 'models'
